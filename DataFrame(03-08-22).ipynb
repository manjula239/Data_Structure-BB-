# %% [markdown]
# ## create data frame froman excel spreadsheet

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\user\OneDrive\Documents\emp.xlsx")
df
# Out:
#    empid ename         job        doj
# 0   1001   aaa     manager 2016-04-03
# 1   1002   bbb       clerk 2015-01-01
# 2   1003   ccc    salesman 2017-05-09
# 3   1004   ddd  operations 2015-06-11

# %% [markdown]
# ## Creating data frame from .csv file

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\dataframe\test.csv")
df
# Out:
#    empid   ename  salary         job
# 0   1000   gopal   34000     manager
# 1   1001  suresh   45000  operations
# 2   1002  naresh   23000   marketing

# %% [markdown]
# ## Creating data frame from html file

# %%
df=pd.read_html(r"https://www.livingin-canada.com/house-prices-canada.html")
df
# Out:
# [                                                City  \
#  0                                      Vancouver, BC
#  1                                       Toronto, Ont
#  2                                        Ottawa, Ont
#  3                                       Calgary, Alb
#  4                                      Montreal, Que
#  5                                        Halifax, NS
#  6                                       Regina, Sask
#  7                                    Fredericton, NB
#  8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
#  0                                         $1,036,000
#  1                                           $870,000
#  2                                           $479,000
#  3                                           $410,000
#  4                                           $435,000
#  5                                           $331,000
# ...

# %%
df=pd.read_html("https://www.livingin-canada.com/house-prices-canada.html")
df[0]
# Out:
#                                                 City  \
# 0                                      Vancouver, BC
# 1                                       Toronto, Ont
# 2                                        Ottawa, Ont
# 3                                       Calgary, Alb
# 4                                      Montreal, Que
# 5                                        Halifax, NS
# 6                                       Regina, Sask
# 7                                    Fredericton, NB
# 8  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                  Average House Price  \
# 0                                         $1,036,000
# 1                                           $870,000
# 2                                           $479,000
# 3                                           $410,000
# 4                                           $435,000
# 5                                           $331,000
# 6                                           $254,000
# ...

# %%
df=pd.read_html(r"https://www.livingin-canada.com/house-prices-canada.html")
df[1]
# Out:
#                                              Province  \
# 0                                    British Columbia
# 1                                             Ontario
# 2                                             Alberta
# 3                                              Quebec
# 4                                            Manitoba
# 5                                        Saskatchewan
# 6                                         Nova Scotia
# 7                                Prince Edward Island
# 8                             Newfoundland / Labrador
# 9                                       New Brunswick
# 10                                   Canadian Average
# 11  (adsbygoogle = window.adsbygoogle || []).push(...
#
#                                   Average House Price  \
# 0                                            $736,000
# 1                                            $594,000
# 2                                            $353,000
# ...

# %%
df=pd.read_html(r"https://www.livingin-canada.com/house-prices-canada.html")
df[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 df=pd.read_html(r"https://www.livingin-canada.com/house-prices-canada.html")
# ----> 2 df[2]
#
# IndexError: list index out of range
